# %%
import json
import os
import sys

import pandas as pd
from Prompter.prompter import Prompter

# %%
CHECKPOINTS = './checkpoints/'


def parse_checkpoint_file(filename):
	filepath = os.path.join(CHECKPOINTS, filename)
	if not os.path.exists(filepath):
		print(f"Checkpoint file {filepath} does not exist.")
		sys.exit(1)


	filename = filename.split('.json')[0]
	model = filename.split('_temp_')[0]
	temperature = filename.split('_temp_')[1].split('_rep_')[0]
	repetition = filename.split('_rep_')[1].split('_')[0]
	question_type = filename.split('_')[-1]

	# Load the JSON file
	with open(filepath, 'r') as f:
		checkpoint_data = json.load(f)

	return model, temperature, repetition, question_type, checkpoint_data


def list_files(directory):
	files = []
	for filename in os.listdir(directory):
		if filename.endswith(".json"):
			files.append(filename)
	return files

print("Listing all the files in the directory...", list_files('./checkpoints/'))
MAIN_FILE = 'prompt_plan_updated.json'
files = list_files(CHECKPOINTS)
for filename in files:
	model, temp, rep, q, data = parse_checkpoint_file(filename)
	print("Parsed checkpoint:", filename)
# Out:
# Listing all the files in the directory... ['Athene-v2-Chat-72B_temp_0.0_rep_1_cq.json', 'Athene-v2-Chat-72B_temp_0.0_rep_1_task.json', 'Athene-v2-Chat-72B_temp_0.3_rep_1_cq.json', 'Athene-v2-Chat-72B_temp_0.3_rep_1_task.json', 'Athene-v2-Chat-72B_temp_0.7_rep_1_cq.json', 'Athene-v2-Chat-72B_temp_0.7_rep_1_task.json', 'Athene-v2-Chat-72B_temp_1.0_rep_1_cq.json', 'Athene-v2-Chat-72B_temp_1.0_rep_1_task.json', 'ChatGPT-4o-latest (2025-01-29)_temp_0.0_rep_1_cq.json', 'ChatGPT-4o-latest (2025-01-29)_temp_0.0_rep_1_task.json', 'ChatGPT-4o-latest (2025-01-29)_temp_0.3_rep_1_cq.json', 'ChatGPT-4o-latest (2025-01-29)_temp_0.3_rep_1_task.json', 'ChatGPT-4o-latest (2025-01-29)_temp_0.7_rep_1_cq.json', 'ChatGPT-4o-latest (2025-01-29)_temp_0.7_rep_1_task.json', 'ChatGPT-4o-latest (2025-01-29)_temp_1.0_rep_1_cq.json', 'ChatGPT-4o-latest (2025-01-29)_temp_1.0_rep_1_task.json', 'Command A (03-2025)_temp_0.0_rep_1_cq.json', 'Command A (03-2025)_temp_0.0_rep_1_task.json', 'Command A (03-2025)_temp_0.3_rep_1_cq.json', 'Command A (03-2025)_temp_0.3_rep_1_task.json', 'Command A (03-2025)_temp_0.7_rep_1_cq.json', 'Command A (03-2025)_temp_0.7_rep_1_task.json', 'Command A (03-2025)_temp_1.0_rep_1_cq.json', 'Command A (03-2025)_temp_1.0_rep_1_task.json', 'DeepSeek-R1_temp_0.0_rep_1_cq.json', 'DeepSeek-R1_temp_0.0_rep_1_task.json', 'DeepSeek-R1_temp_0.3_rep_1_cq.json', 'DeepSeek-R1_temp_0.3_rep_1_task.json', 'DeepSeek-R1_temp_0.7_rep_1_cq.json', 'DeepSeek-R1_temp_0.7_rep_1_task.json', 'DeepSeek-R1_temp_1.0_rep_1_cq.json', 'DeepSeek-R1_temp_1.0_rep_1_task.json', 'DeepSeek-V3_temp_0.0_rep_1_cq.json', 'DeepSeek-V3_temp_0.0_rep_1_task.json', 'DeepSeek-V3_temp_0.3_rep_1_cq.json', 'DeepSeek-V3_temp_0.3_rep_1_task.json', 'DeepSeek-V3_temp_0.7_rep_1_cq.json', 'DeepSeek-V3_temp_0.7_rep_1_task.json', 'DeepSeek-V3_temp_1.0_rep_1_cq.json', 'DeepSeek-V3_temp_1.0_rep_1_task.json', 'Gemini-1.5-Pro-002_temp_0.0_rep_1_cq.json', 'Gemini-1.5-Pro-002_temp_0.0_rep_1_task.json', 'Gemini-1.5-Pro-002_temp_0.3_rep_1_cq.json', 'Gemini-1.5-Pro-002_temp_0.3_rep_1_task.json', 'Gemini-1.5-Pro-002_temp_0.7_rep_1_cq.json', 'Gemini-1.5-Pro-002_temp_0.7_rep_1_task.json', 'Gemini-1.5-Pro-002_temp_1.0_rep_1_cq.json', 'Gemini-1.5-Pro-002_temp_1.0_rep_1_task.json', 'Gemini-2.0-Flash-Thinking-Exp-01-21_temp_0.0_rep_1_cq.json', 'Gemini-2.0-Flash-Thinking-Exp-01-21_temp_0.0_rep_1_task.json', 'Gemini-2.0-Flash-Thinking-Exp-01-21_temp_0.3_rep_1_cq.json', 'Gemini-2.0-Flash-Thinking-Exp-01-21_temp_0.3_rep_1_task.json', 'Gemini-2.0-Flash-Thinking-Exp-01-21_temp_0.7_rep_1_cq.json', 'Gemini-2.0-Flash-Thinking-Exp-01-21_temp_0.7_rep_1_task.json', 'Gemini-2.0-Flash-Thinking-Exp-01-21_temp_1.0_rep_1_cq.json', 'Gemini-2.0-Flash-Thinking-Exp-01-21_temp_1.0_rep_1_task.json', 'Gemma-3-27B-it_temp_0.0_rep_1_cq.json', 'Gemma-3-27B-it_temp_0.0_rep_1_task.json', 'Gemma-3-27B-it_temp_0.3_rep_1_cq.json', 'Gemma-3-27B-it_temp_0.3_rep_1_task.json', 'Gemma-3-27B-it_temp_0.7_rep_1_cq.json', 'Gemma-3-27B-it_temp_0.7_rep_1_task.json', 'Gemma-3-27B-it_temp_1.0_rep_1_cq.json', 'Gemma-3-27B-it_temp_1.0_rep_1_task.json', 'GPT-4.5-Preview_temp_0.0_rep_1_cq.json', 'GPT-4.5-Preview_temp_0.0_rep_1_task.json', 'GPT-4.5-Preview_temp_0.3_rep_1_cq.json', 'GPT-4.5-Preview_temp_0.3_rep_1_task.json', 'GPT-4.5-Preview_temp_0.7_rep_1_cq.json', 'GPT-4.5-Preview_temp_0.7_rep_1_task.json', 'GPT-4.5-Preview_temp_1.0_rep_1_cq.json', 'GPT-4.5-Preview_temp_1.0_rep_1_task.json', 'Llama-3.3-Nemotron-Super-49B-v1_temp_0.0_rep_1_cq.json', 'Llama-3.3-Nemotron-Super-49B-v1_temp_0.0_rep_1_task.json', 'Llama-3.3-Nemotron-Super-49B-v1_temp_0.3_rep_1_cq.json', 'Llama-3.3-Nemotron-Super-49B-v1_temp_0.3_rep_1_task.json', 'Llama-3.3-Nemotron-Super-49B-v1_temp_0.7_rep_1_cq.json', 'Llama-3.3-Nemotron-Super-49B-v1_temp_0.7_rep_1_task.json', 'Llama-3.3-Nemotron-Super-49B-v1_temp_1.0_rep_1_cq.json', 'Llama-3.3-Nemotron-Super-49B-v1_temp_1.0_rep_1_task.json', 'Meta-Llama-3.1-405B-Instruct-bf16_temp_0.0_rep_1_cq.json', 'Meta-Llama-3.1-405B-Instruct-bf16_temp_0 ...
# Parsed checkpoint: {'model': 'Athene-v2-Chat-72B', 'temperature': '0.0', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'Athene-v2-Chat-72B', 'temperature': '0.0', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'Athene-v2-Chat-72B', 'temperature': '0.3', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'Athene-v2-Chat-72B', 'temperature': '0.3', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'Athene-v2-Chat-72B', 'temperature': '0.7', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'Athene-v2-Chat-72B', 'temperature': '0.7', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'Athene-v2-Chat-72B', 'temperature': '1.0', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'Athene-v2-Chat-72B', 'temperature': '1.0', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'ChatGPT-4o-latest (2025-01-29)', 'temperature': '0.0', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'ChatGPT-4o-latest (2025-01-29)', 'temperature': '0.0', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'ChatGPT-4o-latest (2025-01-29)', 'temperature': '0.3', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'ChatGPT-4o-latest (2025-01-29)', 'temperature': '0.3', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'ChatGPT-4o-latest (2025-01-29)', 'temperature': '0.7', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'ChatGPT-4o-latest (2025-01-29)', 'temperature': '0.7', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'ChatGPT-4o-latest (2025-01-29)', 'temperature': '1.0', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'ChatGPT-4o-latest (2025-01-29)', 'temperature': '1.0', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'Command A (03-2025)', 'temperature': '0.0', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'Command A (03-2025)', 'temperature': '0.0', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'Command A (03-2025)', 'temperature': '0.3', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'Command A (03-2025)', 'temperature': '0.3', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'Command A (03-2025)', 'temperature': '0.7', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'Command A (03-2025)', 'temperature': '0.7', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'Command A (03-2025)', 'temperature': '1.0', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'Command A (03-2025)', 'temperature': '1.0', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'DeepSeek-R1', 'temperature': '0.0', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'DeepSeek-R1', 'temperature': '0.0', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'DeepSeek-R1', 'temperature': '0.3', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'DeepSeek-R1', 'temperature': '0.3', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'DeepSeek-R1', 'temperature': '0.7', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'DeepSeek-R1', 'temperature': '0.7', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'DeepSeek-R1', 'temperature': '1.0', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'DeepSeek-R1', 'temperature': '1.0', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'DeepSeek-V3', 'temperature': '0.0', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'DeepSeek-V3', 'temperature': '0.0', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'DeepSeek-V3', 'temperature': '0.3', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'DeepSeek-V3', 'temperature': '0.3', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'DeepSeek-V3', 'temperature': '0.7', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'DeepSeek-V3', 'temperature': '0.7', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'DeepSeek-V3', 'temperature': '1.0', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'DeepSeek-V3', 'temperature': '1.0', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'Gemini-1.5-Pro-002', 'temperature': '0.0', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'Gemini-1.5-Pro-002', 'temperature': '0.0', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'Gemini-1.5-Pro-002', 'temperature': '0.3', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'Gemini-1.5-Pro-002', 'temperature': '0.3', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'Gemini-1.5-Pro-002', 'temperature': '0.7', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'Gemini-1.5-Pro-002', 'temperature': '0.7', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'Gemini-1.5-Pro-002', 'temperature': '1.0', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'Gemini-1.5-Pro-002', 'temperature': '1.0', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'Gemini-2.0-Flash-Thinking-Exp-01-21', 'temperature': '0.0', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'Gemini-2.0-Flash-Thinking-Exp-01-21', 'temperature': '0.0', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'Gemini-2.0-Flash-Thinking-Exp-01-21', 'temperature': '0.3', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'Gemini-2.0-Flash-Thinking-Exp-01-21', 'temperature': '0.3', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'Gemini-2.0-Flash-Thinking-Exp-01-21', 'temperature': '0.7', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'Gemini-2.0-Flash-Thinking-Exp-01-21', 'temperature': '0.7', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'Gemini-2.0-Flash-Thinking-Exp-01-21', 'temperature': '1.0', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'Gemini-2.0-Flash-Thinking-Exp-01-21', 'temperature': '1.0', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'Gemma-3-27B-it', 'temperature': '0.0', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'Gemma-3-27B-it', 'temperature': '0.0', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'Gemma-3-27B-it', 'temperature': '0.3', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'Gemma-3-27B-it', 'temperature': '0.3', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'Gemma-3-27B-it', 'temperature': '0.7', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'Gemma-3-27B-it', 'temperature': '0.7', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'Gemma-3-27B-it', 'temperature': '1.0', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'Gemma-3-27B-it', 'temperature': '1.0', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'GPT-4.5-Preview', 'temperature': '0.0', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'GPT-4.5-Preview', 'temperature': '0.0', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'GPT-4.5-Preview', 'temperature': '0.3', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'GPT-4.5-Preview', 'temperature': '0.3', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'GPT-4.5-Preview', 'temperature': '0.7', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'GPT-4.5-Preview', 'temperature': '0.7', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'GPT-4.5-Preview', 'temperature': '1.0', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'GPT-4.5-Preview', 'temperature': '1.0', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'Llama-3.3-Nemotron-Super-49B-v1', 'temperature': '0.0', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'Llama-3.3-Nemotron-Super-49B-v1', 'temperature': '0.0', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'Llama-3.3-Nemotron-Super-49B-v1', 'temperature': '0.3', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'Llama-3.3-Nemotron-Super-49B-v1', 'temperature': '0.3', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'Llama-3.3-Nemotron-Super-49B-v1', 'temperature': '0.7', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'Llama-3.3-Nemotron-Super-49B-v1', 'temperature': '0.7', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'Llama-3.3-Nemotron-Super-49B-v1', 'temperature': '1.0', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'Llama-3.3-Nemotron-Super-49B-v1', 'temperature': '1.0', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'Meta-Llama-3.1-405B-Instruct-bf16', 'temperature': '0.0', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'Meta-Llama-3.1-405B-Instruct-bf16', 'temperature': '0.0', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'Meta-Llama-3.1-405B-Instruct-bf16', 'temperature': '0.3', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'Meta-Llama-3.1-405B-Instruct-bf16', 'temperature': '0.3', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'Meta-Llama-3.1-405B-Instruct-bf16', 'temperature': '0.7', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'Meta-Llama-3.1-405B-Instruct-bf16', 'temperature': '0.7', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'Meta-Llama-3.1-405B-Instruct-bf16', 'temperature': '1.0', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'Meta-Llama-3.1-405B-Instruct-bf16', 'temperature': '1.0', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'Mistral-Large-2407', 'temperature': '0.0', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'Mistral-Large-2407', 'temperature': '0.0', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'Mistral-Large-2407', 'temperature': '0.3', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'Mistral-Large-2407', 'temperature': '0.3', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'Mistral-Large-2407', 'temperature': '0.7', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'Mistral-Large-2407', 'temperature': '0.7', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'Mistral-Large-2407', 'temperature': '1.0', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'Mistral-Large-2407', 'temperature': '1.0', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'o1-mini', 'temperature': '0.0', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'o1-mini', 'temperature': '0.0', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'o1-mini', 'temperature': '0.3', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'o1-mini', 'temperature': '0.3', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'o1-mini', 'temperature': '0.7', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'o1-mini', 'temperature': '0.7', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'o1-mini', 'temperature': '1.0', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'o1-mini', 'temperature': '1.0', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'o3-mini', 'temperature': '0.0', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'o3-mini', 'temperature': '0.0', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'o3-mini', 'temperature': '0.3', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'o3-mini', 'temperature': '0.3', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'o3-mini', 'temperature': '0.7', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'o3-mini', 'temperature': '0.7', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'o3-mini', 'temperature': '1.0', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'o3-mini', 'temperature': '1.0', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'Qwen-Plus-0125', 'temperature': '0.0', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'Qwen-Plus-0125', 'temperature': '0.0', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'Qwen-Plus-0125', 'temperature': '0.3', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'Qwen-Plus-0125', 'temperature': '0.3', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'Qwen-Plus-0125', 'temperature': '0.7', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'Qwen-Plus-0125', 'temperature': '0.7', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'Qwen-Plus-0125', 'temperature': '1.0', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'Qwen-Plus-0125', 'temperature': '1.0', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'Qwen2.5-Max', 'temperature': '0.0', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'Qwen2.5-Max', 'temperature': '0.0', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'Qwen2.5-Max', 'temperature': '0.3', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'Qwen2.5-Max', 'temperature': '0.3', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'Qwen2.5-Max', 'temperature': '0.7', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'Qwen2.5-Max', 'temperature': '0.7', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'Qwen2.5-Max', 'temperature': '1.0', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'Qwen2.5-Max', 'temperature': '1.0', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'QwQ-32B', 'temperature': '0.0', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'QwQ-32B', 'temperature': '0.0', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'QwQ-32B', 'temperature': '0.3', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'QwQ-32B', 'temperature': '0.3', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'QwQ-32B', 'temperature': '0.7', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'QwQ-32B', 'temperature': '0.7', 'repetition': '1', 'question_type': 'task'}
# Parsed checkpoint: {'model': 'QwQ-32B', 'temperature': '1.0', 'repetition': '1', 'question_type': 'cq'}
# Parsed checkpoint: {'model': 'QwQ-32B', 'temperature': '1.0', 'repetition': '1', 'question_type': 'task'}

# %%
# Merge files with 1 rep
with open('prompts_plan_TOP_5_1_REP.json', 'r') as first:
	data_1 = json.load(first)
with open('prompts_plan_NEXT_5_1_REP.json', 'r') as second:
	data_2 = json.load(second)

with open('prompts_plan_merged_1_REP.json', 'w') as output:
	data_1['prompts'].extend(data_2['prompts'])
	json.dump(data_1, output, indent=4)

# %%
# Big Merge
with open('prompts_plan_merged_1_REP.json', 'r') as completed:
	data_completed = json.load(completed)

with open('prompts_plan.json', 'r') as incomplete:
	data_incomplete = json.load(incomplete)

for llm_id, llms in enumerate(data_completed['prompts']):
	llm = llms['llm']

	# Check if the model is in the incomplete data
	if llm not in [llm['llm'] for llm in data_incomplete['prompts']]:
		continue

	# Find the corresponding model in the incomplete data
	incomplete_llm = next(item for item in data_incomplete['prompts'] if item['llm'] == llm)		

	for temperature_id, temperatures in enumerate(llms['prompts']):
		temperature = temperatures['temperature_level']
		# Check if the temperature is in the incomplete data
		if temperature not in [temp['temperature_level'] for temp in incomplete_llm['prompts']]:
			continue

		# Find the corresponding temperature in the incomplete data
		incomplete_temperature = next(item for item in incomplete_llm['prompts'] if item['temperature_level'] == temperature)

		for cq_rep, cqs in enumerate(temperatures['comprehension_questions']):
			repetition = cqs['repetition_id']
			# Check if the repetition is in the incomplete data
			if repetition not in [rep['repetition_id'] for rep in incomplete_temperature['comprehension_questions']]:
				continue
			# Find the corresponding repetition in the incomplete data
			incomplete_comprehension = next(item for item in incomplete_temperature['comprehension_questions'] if item['repetition_id'] == repetition)

			
			for prompt_id, comprehension_question in enumerate(cqs['prompts']):
				prompt = comprehension_question['prompt']
				format_answer = comprehension_question['format_answer']

				# Check if the prompt is in the incomplete data
				if prompt not in [prompt['prompt'] for prompt in incomplete_comprehension['prompts']]:
					continue

				# Find the corresponding prompt in the incomplete data
				incomplete_prompt = next(item for item in incomplete_comprehension['prompts'] if (item['prompt'] == prompt and item['format_answer'] == format_answer))

				if "answer" in comprehension_question:
					incomplete_prompt['answer'] = comprehension_question['answer']
					print(f"Added answer to prompt: {comprehension_question['prompt_type']} for model: {llm}, temperature: {temperature}, repetition: {repetition}")
				else:
					print(f"Prompt: {comprehension_question['prompt_type']} for model: {llm}, temperature: {temperature}, repetition: {repetition} does not have an answer.")
					
		for cq_rep, cqs in enumerate(temperatures['tasks']):
			repetition = cqs['repetition_id']
			# Check if the repetition is in the incomplete data
			if repetition not in [rep['repetition_id'] for rep in incomplete_temperature['tasks']]:
				continue
			# Find the corresponding repetition in the incomplete data
			incomplete_comprehension = next(item for item in incomplete_temperature['tasks'] if item['repetition_id'] == repetition)

			
			for prompt_id, comprehension_question in enumerate(cqs['prompts']):
				prompt = comprehension_question['prompt']
				format_answer = comprehension_question['format_answer']

				# Check if the prompt is in the incomplete data
				if prompt not in [prompt['prompt'] for prompt in incomplete_comprehension['prompts']]:
					continue

				# Find the corresponding prompt in the incomplete data
				incomplete_prompt = next(item for item in incomplete_comprehension['prompts'] if (item['prompt'] == prompt and item['format_answer'] == format_answer))

				if "answer" in comprehension_question:
					incomplete_prompt['answer'] = comprehension_question['answer']
					print(f"Added answer to prompt: {comprehension_question['id']} for model: {llm}, temperature: {temperature}, repetition: {repetition}")
				else:
					print(f"Prompt: {comprehension_question['id']} for model: {llm}, temperature: {temperature}, repetition: {repetition} does not have an answer.")

			
with open('prompts_plan_merged.json', 'w') as output:
	json.dump(data_incomplete, output, indent=4)
	print("Merged data saved to prompts_plan_merged.json")
# Out:
# Added answer to prompt: cq_1 for model: GPT-4.5-Preview, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_1 for model: GPT-4.5-Preview, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_2 for model: GPT-4.5-Preview, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_2 for model: GPT-4.5-Preview, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_3 for model: GPT-4.5-Preview, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_3 for model: GPT-4.5-Preview, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_4 for model: GPT-4.5-Preview, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_4 for model: GPT-4.5-Preview, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_5 for model: GPT-4.5-Preview, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_5 for model: GPT-4.5-Preview, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_6 for model: GPT-4.5-Preview, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_6 for model: GPT-4.5-Preview, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_7 for model: GPT-4.5-Preview, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_7 for model: GPT-4.5-Preview, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_8 for model: GPT-4.5-Preview, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_8 for model: GPT-4.5-Preview, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_9 for model: GPT-4.5-Preview, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_9 for model: GPT-4.5-Preview, temperature: 0.0, repetition: 1
# Added answer to prompt: 19 for model: GPT-4.5-Preview, temperature: 0.0, repetition: 1
# Added answer to prompt: 20 for model: GPT-4.5-Preview, temperature: 0.0, repetition: 1
# Added answer to prompt: 21 for model: GPT-4.5-Preview, temperature: 0.0, repetition: 1
# Added answer to prompt: 22 for model: GPT-4.5-Preview, temperature: 0.0, repetition: 1
# Added answer to prompt: 23 for model: GPT-4.5-Preview, temperature: 0.0, repetition: 1
# Added answer to prompt: 24 for model: GPT-4.5-Preview, temperature: 0.0, repetition: 1
# Added answer to prompt: 25 for model: GPT-4.5-Preview, temperature: 0.0, repetition: 1
# Added answer to prompt: 26 for model: GPT-4.5-Preview, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_4 for model: GPT-4.5-Preview, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_4 for model: GPT-4.5-Preview, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_5 for model: GPT-4.5-Preview, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_5 for model: GPT-4.5-Preview, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_6 for model: GPT-4.5-Preview, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_6 for model: GPT-4.5-Preview, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_7 for model: GPT-4.5-Preview, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_7 for model: GPT-4.5-Preview, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_8 for model: GPT-4.5-Preview, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_8 for model: GPT-4.5-Preview, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_9 for model: GPT-4.5-Preview, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_9 for model: GPT-4.5-Preview, temperature: 0.3, repetition: 1
# Added answer to prompt: 45 for model: GPT-4.5-Preview, temperature: 0.3, repetition: 1
# Added answer to prompt: 46 for model: GPT-4.5-Preview, temperature: 0.3, repetition: 1
# Added answer to prompt: 47 for model: GPT-4.5-Preview, temperature: 0.3, repetition: 1
# Added answer to prompt: 48 for model: GPT-4.5-Preview, temperature: 0.3, repetition: 1
# Added answer to prompt: 49 for model: GPT-4.5-Preview, temperature: 0.3, repetition: 1
# Added answer to prompt: 50 for model: GPT-4.5-Preview, temperature: 0.3, repetition: 1
# Added answer to prompt: 51 for model: GPT-4.5-Preview, temperature: 0.3, repetition: 1
# Added answer to prompt: 52 for model: GPT-4.5-Preview, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_1 for model: GPT-4.5-Preview, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_1 for model: GPT-4.5-Preview, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_2 for model: GPT-4.5-Preview, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_2 for model: GPT-4.5-Preview, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_3 for model: GPT-4.5-Preview, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_3 for model: GPT-4.5-Preview, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_4 for model: GPT-4.5-Preview, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_4 for model: GPT-4.5-Preview, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_5 for model: GPT-4.5-Preview, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_5 for model: GPT-4.5-Preview, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_6 for model: GPT-4.5-Preview, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_6 for model: GPT-4.5-Preview, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_7 for model: GPT-4.5-Preview, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_7 for model: GPT-4.5-Preview, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_8 for model: GPT-4.5-Preview, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_8 for model: GPT-4.5-Preview, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_9 for model: GPT-4.5-Preview, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_9 for model: GPT-4.5-Preview, temperature: 0.7, repetition: 1
# Added answer to prompt: 71 for model: GPT-4.5-Preview, temperature: 0.7, repetition: 1
# Added answer to prompt: 72 for model: GPT-4.5-Preview, temperature: 0.7, repetition: 1
# Added answer to prompt: 73 for model: GPT-4.5-Preview, temperature: 0.7, repetition: 1
# Added answer to prompt: 74 for model: GPT-4.5-Preview, temperature: 0.7, repetition: 1
# Added answer to prompt: 75 for model: GPT-4.5-Preview, temperature: 0.7, repetition: 1
# Added answer to prompt: 76 for model: GPT-4.5-Preview, temperature: 0.7, repetition: 1
# Added answer to prompt: 77 for model: GPT-4.5-Preview, temperature: 0.7, repetition: 1
# Added answer to prompt: 78 for model: GPT-4.5-Preview, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_1 for model: GPT-4.5-Preview, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_1 for model: GPT-4.5-Preview, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_2 for model: GPT-4.5-Preview, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_2 for model: GPT-4.5-Preview, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_3 for model: GPT-4.5-Preview, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_3 for model: GPT-4.5-Preview, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_4 for model: GPT-4.5-Preview, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_4 for model: GPT-4.5-Preview, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_5 for model: GPT-4.5-Preview, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_5 for model: GPT-4.5-Preview, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_6 for model: GPT-4.5-Preview, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_6 for model: GPT-4.5-Preview, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_7 for model: GPT-4.5-Preview, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_7 for model: GPT-4.5-Preview, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_8 for model: GPT-4.5-Preview, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_8 for model: GPT-4.5-Preview, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_9 for model: GPT-4.5-Preview, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_9 for model: GPT-4.5-Preview, temperature: 1.0, repetition: 1
# Added answer to prompt: 97 for model: GPT-4.5-Preview, temperature: 1.0, repetition: 1
# Added answer to prompt: 98 for model: GPT-4.5-Preview, temperature: 1.0, repetition: 1
# Added answer to prompt: 99 for model: GPT-4.5-Preview, temperature: 1.0, repetition: 1
# Added answer to prompt: 100 for model: GPT-4.5-Preview, temperature: 1.0, repetition: 1
# Added answer to prompt: 101 for model: GPT-4.5-Preview, temperature: 1.0, repetition: 1
# Added answer to prompt: 102 for model: GPT-4.5-Preview, temperature: 1.0, repetition: 1
# Added answer to prompt: 103 for model: GPT-4.5-Preview, temperature: 1.0, repetition: 1
# Added answer to prompt: 104 for model: GPT-4.5-Preview, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_1 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_1 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_2 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_2 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_3 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_3 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_4 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_4 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_5 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_5 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_6 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_6 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_7 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_7 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_8 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_8 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_9 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_9 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.0, repetition: 1
# Added answer to prompt: 123 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.0, repetition: 1
# Added answer to prompt: 124 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.0, repetition: 1
# Added answer to prompt: 125 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.0, repetition: 1
# Added answer to prompt: 126 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.0, repetition: 1
# Added answer to prompt: 127 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.0, repetition: 1
# Added answer to prompt: 128 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.0, repetition: 1
# Added answer to prompt: 129 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.0, repetition: 1
# Added answer to prompt: 130 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_1 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_1 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_2 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_2 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_3 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_3 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_4 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_4 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_5 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_5 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_6 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_6 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_7 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_7 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_8 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_8 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_9 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_9 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.3, repetition: 1
# Added answer to prompt: 149 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.3, repetition: 1
# Added answer to prompt: 150 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.3, repetition: 1
# Added answer to prompt: 151 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.3, repetition: 1
# Added answer to prompt: 152 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.3, repetition: 1
# Added answer to prompt: 153 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.3, repetition: 1
# Added answer to prompt: 154 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.3, repetition: 1
# Added answer to prompt: 155 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.3, repetition: 1
# Added answer to prompt: 156 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_1 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_1 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_2 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_2 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_3 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_3 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_4 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_4 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_5 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_5 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_6 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_6 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_7 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_7 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_8 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_8 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_9 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_9 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.7, repetition: 1
# Added answer to prompt: 175 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.7, repetition: 1
# Added answer to prompt: 176 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.7, repetition: 1
# Added answer to prompt: 177 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.7, repetition: 1
# Added answer to prompt: 178 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.7, repetition: 1
# Added answer to prompt: 179 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.7, repetition: 1
# Added answer to prompt: 180 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.7, repetition: 1
# Added answer to prompt: 181 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.7, repetition: 1
# Added answer to prompt: 182 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_1 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_1 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_2 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_2 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_3 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_3 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_4 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_4 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_5 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_5 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_6 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_6 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_7 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_7 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_8 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_8 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_9 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_9 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 1.0, repetition: 1
# Added answer to prompt: 201 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 1.0, repetition: 1
# Added answer to prompt: 202 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 1.0, repetition: 1
# Added answer to prompt: 203 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 1.0, repetition: 1
# Added answer to prompt: 204 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 1.0, repetition: 1
# Added answer to prompt: 205 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 1.0, repetition: 1
# Added answer to prompt: 206 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 1.0, repetition: 1
# Added answer to prompt: 207 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 1.0, repetition: 1
# Added answer to prompt: 208 for model: Gemini-2.0-Flash-Thinking-Exp-01-21, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_1 for model: o1-2024-12-17, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_1 for model: o1-2024-12-17, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_2 for model: o1-2024-12-17, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_2 for model: o1-2024-12-17, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_3 for model: o1-2024-12-17, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_3 for model: o1-2024-12-17, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_4 for model: o1-2024-12-17, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_4 for model: o1-2024-12-17, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_5 for model: o1-2024-12-17, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_5 for model: o1-2024-12-17, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_6 for model: o1-2024-12-17, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_6 for model: o1-2024-12-17, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_7 for model: o1-2024-12-17, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_7 for model: o1-2024-12-17, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_8 for model: o1-2024-12-17, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_8 for model: o1-2024-12-17, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_9 for model: o1-2024-12-17, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_9 for model: o1-2024-12-17, temperature: 0.0, repetition: 1
# Added answer to prompt: 227 for model: o1-2024-12-17, temperature: 0.0, repetition: 1
# Added answer to prompt: 228 for model: o1-2024-12-17, temperature: 0.0, repetition: 1
# Added answer to prompt: 229 for model: o1-2024-12-17, temperature: 0.0, repetition: 1
# Added answer to prompt: 230 for model: o1-2024-12-17, temperature: 0.0, repetition: 1
# Added answer to prompt: 231 for model: o1-2024-12-17, temperature: 0.0, repetition: 1
# Added answer to prompt: 232 for model: o1-2024-12-17, temperature: 0.0, repetition: 1
# Added answer to prompt: 233 for model: o1-2024-12-17, temperature: 0.0, repetition: 1
# Added answer to prompt: 234 for model: o1-2024-12-17, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_1 for model: o1-2024-12-17, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_1 for model: o1-2024-12-17, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_2 for model: o1-2024-12-17, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_2 for model: o1-2024-12-17, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_3 for model: o1-2024-12-17, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_3 for model: o1-2024-12-17, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_4 for model: o1-2024-12-17, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_4 for model: o1-2024-12-17, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_5 for model: o1-2024-12-17, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_5 for model: o1-2024-12-17, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_6 for model: o1-2024-12-17, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_6 for model: o1-2024-12-17, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_7 for model: o1-2024-12-17, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_7 for model: o1-2024-12-17, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_8 for model: o1-2024-12-17, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_8 for model: o1-2024-12-17, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_9 for model: o1-2024-12-17, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_9 for model: o1-2024-12-17, temperature: 0.3, repetition: 1
# Added answer to prompt: 253 for model: o1-2024-12-17, temperature: 0.3, repetition: 1
# Added answer to prompt: 254 for model: o1-2024-12-17, temperature: 0.3, repetition: 1
# Added answer to prompt: 255 for model: o1-2024-12-17, temperature: 0.3, repetition: 1
# Added answer to prompt: 256 for model: o1-2024-12-17, temperature: 0.3, repetition: 1
# Added answer to prompt: 257 for model: o1-2024-12-17, temperature: 0.3, repetition: 1
# Added answer to prompt: 258 for model: o1-2024-12-17, temperature: 0.3, repetition: 1
# Added answer to prompt: 259 for model: o1-2024-12-17, temperature: 0.3, repetition: 1
# Added answer to prompt: 260 for model: o1-2024-12-17, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_1 for model: o1-2024-12-17, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_1 for model: o1-2024-12-17, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_2 for model: o1-2024-12-17, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_2 for model: o1-2024-12-17, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_3 for model: o1-2024-12-17, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_3 for model: o1-2024-12-17, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_4 for model: o1-2024-12-17, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_4 for model: o1-2024-12-17, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_5 for model: o1-2024-12-17, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_5 for model: o1-2024-12-17, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_6 for model: o1-2024-12-17, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_6 for model: o1-2024-12-17, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_7 for model: o1-2024-12-17, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_7 for model: o1-2024-12-17, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_8 for model: o1-2024-12-17, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_8 for model: o1-2024-12-17, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_9 for model: o1-2024-12-17, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_9 for model: o1-2024-12-17, temperature: 0.7, repetition: 1
# Added answer to prompt: 279 for model: o1-2024-12-17, temperature: 0.7, repetition: 1
# Added answer to prompt: 280 for model: o1-2024-12-17, temperature: 0.7, repetition: 1
# Added answer to prompt: 281 for model: o1-2024-12-17, temperature: 0.7, repetition: 1
# Added answer to prompt: 282 for model: o1-2024-12-17, temperature: 0.7, repetition: 1
# Added answer to prompt: 283 for model: o1-2024-12-17, temperature: 0.7, repetition: 1
# Added answer to prompt: 284 for model: o1-2024-12-17, temperature: 0.7, repetition: 1
# Added answer to prompt: 285 for model: o1-2024-12-17, temperature: 0.7, repetition: 1
# Added answer to prompt: 286 for model: o1-2024-12-17, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_1 for model: o1-2024-12-17, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_1 for model: o1-2024-12-17, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_2 for model: o1-2024-12-17, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_2 for model: o1-2024-12-17, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_3 for model: o1-2024-12-17, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_3 for model: o1-2024-12-17, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_4 for model: o1-2024-12-17, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_4 for model: o1-2024-12-17, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_5 for model: o1-2024-12-17, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_5 for model: o1-2024-12-17, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_6 for model: o1-2024-12-17, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_6 for model: o1-2024-12-17, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_7 for model: o1-2024-12-17, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_7 for model: o1-2024-12-17, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_8 for model: o1-2024-12-17, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_8 for model: o1-2024-12-17, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_9 for model: o1-2024-12-17, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_9 for model: o1-2024-12-17, temperature: 1.0, repetition: 1
# Added answer to prompt: 305 for model: o1-2024-12-17, temperature: 1.0, repetition: 1
# Added answer to prompt: 306 for model: o1-2024-12-17, temperature: 1.0, repetition: 1
# Added answer to prompt: 307 for model: o1-2024-12-17, temperature: 1.0, repetition: 1
# Added answer to prompt: 308 for model: o1-2024-12-17, temperature: 1.0, repetition: 1
# Added answer to prompt: 309 for model: o1-2024-12-17, temperature: 1.0, repetition: 1
# Added answer to prompt: 310 for model: o1-2024-12-17, temperature: 1.0, repetition: 1
# Added answer to prompt: 311 for model: o1-2024-12-17, temperature: 1.0, repetition: 1
# Added answer to prompt: 312 for model: o1-2024-12-17, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_1 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.0, repetition: 1
# Added answer to prompt: cq_1 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.0, repetition: 1
# Added answer to prompt: cq_2 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.0, repetition: 1
# Added answer to prompt: cq_2 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.0, repetition: 1
# Added answer to prompt: cq_3 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.0, repetition: 1
# Added answer to prompt: cq_3 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.0, repetition: 1
# Added answer to prompt: cq_4 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.0, repetition: 1
# Added answer to prompt: cq_4 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.0, repetition: 1
# Added answer to prompt: cq_5 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.0, repetition: 1
# Added answer to prompt: cq_5 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.0, repetition: 1
# Added answer to prompt: cq_6 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.0, repetition: 1
# Added answer to prompt: cq_6 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.0, repetition: 1
# Added answer to prompt: cq_7 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.0, repetition: 1
# Added answer to prompt: cq_7 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.0, repetition: 1
# Added answer to prompt: cq_8 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.0, repetition: 1
# Added answer to prompt: cq_8 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.0, repetition: 1
# Added answer to prompt: cq_9 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.0, repetition: 1
# Added answer to prompt: cq_9 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.0, repetition: 1
# Added answer to prompt: 331 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.0, repetition: 1
# Added answer to prompt: 332 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.0, repetition: 1
# Added answer to prompt: 333 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.0, repetition: 1
# Added answer to prompt: 334 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.0, repetition: 1
# Added answer to prompt: 335 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.0, repetition: 1
# Added answer to prompt: 336 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.0, repetition: 1
# Added answer to prompt: 337 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.0, repetition: 1
# Added answer to prompt: 338 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.0, repetition: 1
# Added answer to prompt: cq_1 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.3, repetition: 1
# Added answer to prompt: cq_1 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.3, repetition: 1
# Added answer to prompt: cq_2 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.3, repetition: 1
# Added answer to prompt: cq_2 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.3, repetition: 1
# Added answer to prompt: cq_3 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.3, repetition: 1
# Added answer to prompt: cq_3 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.3, repetition: 1
# Added answer to prompt: cq_4 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.3, repetition: 1
# Added answer to prompt: cq_4 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.3, repetition: 1
# Added answer to prompt: cq_5 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.3, repetition: 1
# Added answer to prompt: cq_5 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.3, repetition: 1
# Added answer to prompt: cq_6 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.3, repetition: 1
# Added answer to prompt: cq_6 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.3, repetition: 1
# Added answer to prompt: cq_7 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.3, repetition: 1
# Added answer to prompt: cq_7 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.3, repetition: 1
# Added answer to prompt: cq_8 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.3, repetition: 1
# Added answer to prompt: cq_8 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.3, repetition: 1
# Added answer to prompt: cq_9 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.3, repetition: 1
# Added answer to prompt: cq_9 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.3, repetition: 1
# Added answer to prompt: 357 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.3, repetition: 1
# Added answer to prompt: 358 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.3, repetition: 1
# Added answer to prompt: 359 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.3, repetition: 1
# Added answer to prompt: 360 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.3, repetition: 1
# Added answer to prompt: 361 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.3, repetition: 1
# Added answer to prompt: 362 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.3, repetition: 1
# Added answer to prompt: 363 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.3, repetition: 1
# Added answer to prompt: 364 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.3, repetition: 1
# Added answer to prompt: cq_1 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.7, repetition: 1
# Added answer to prompt: cq_1 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.7, repetition: 1
# Added answer to prompt: cq_2 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.7, repetition: 1
# Added answer to prompt: cq_2 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.7, repetition: 1
# Added answer to prompt: cq_3 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.7, repetition: 1
# Added answer to prompt: cq_3 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.7, repetition: 1
# Added answer to prompt: cq_4 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.7, repetition: 1
# Added answer to prompt: cq_4 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.7, repetition: 1
# Added answer to prompt: cq_5 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.7, repetition: 1
# Added answer to prompt: cq_5 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.7, repetition: 1
# Added answer to prompt: cq_6 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.7, repetition: 1
# Added answer to prompt: cq_6 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.7, repetition: 1
# Added answer to prompt: cq_7 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.7, repetition: 1
# Added answer to prompt: cq_7 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.7, repetition: 1
# Added answer to prompt: cq_8 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.7, repetition: 1
# Added answer to prompt: cq_8 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.7, repetition: 1
# Added answer to prompt: cq_9 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.7, repetition: 1
# Added answer to prompt: cq_9 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.7, repetition: 1
# Added answer to prompt: 383 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.7, repetition: 1
# Added answer to prompt: 384 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.7, repetition: 1
# Added answer to prompt: 385 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.7, repetition: 1
# Added answer to prompt: 386 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.7, repetition: 1
# Added answer to prompt: 387 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.7, repetition: 1
# Added answer to prompt: 388 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.7, repetition: 1
# Added answer to prompt: 389 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.7, repetition: 1
# Added answer to prompt: 390 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 0.7, repetition: 1
# Added answer to prompt: cq_1 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 1.0, repetition: 1
# Added answer to prompt: cq_1 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 1.0, repetition: 1
# Added answer to prompt: cq_2 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 1.0, repetition: 1
# Added answer to prompt: cq_2 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 1.0, repetition: 1
# Added answer to prompt: cq_3 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 1.0, repetition: 1
# Added answer to prompt: cq_3 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 1.0, repetition: 1
# Added answer to prompt: cq_4 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 1.0, repetition: 1
# Added answer to prompt: cq_4 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 1.0, repetition: 1
# Added answer to prompt: cq_5 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 1.0, repetition: 1
# Added answer to prompt: cq_5 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 1.0, repetition: 1
# Added answer to prompt: cq_6 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 1.0, repetition: 1
# Added answer to prompt: cq_6 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 1.0, repetition: 1
# Added answer to prompt: cq_7 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 1.0, repetition: 1
# Added answer to prompt: cq_7 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 1.0, repetition: 1
# Added answer to prompt: cq_8 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 1.0, repetition: 1
# Added answer to prompt: cq_8 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 1.0, repetition: 1
# Added answer to prompt: cq_9 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 1.0, repetition: 1
# Added answer to prompt: cq_9 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 1.0, repetition: 1
# Added answer to prompt: 409 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 1.0, repetition: 1
# Added answer to prompt: 410 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 1.0, repetition: 1
# Added answer to prompt: 411 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 1.0, repetition: 1
# Added answer to prompt: 412 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 1.0, repetition: 1
# Added answer to prompt: 413 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 1.0, repetition: 1
# Added answer to prompt: 414 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 1.0, repetition: 1
# Added answer to prompt: 415 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 1.0, repetition: 1
# Added answer to prompt: 416 for model: Claude 3.7 Sonnet (thinking-32k), temperature: 1.0, repetition: 1
# Added answer to prompt: cq_1 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.0, repetition: 1
# Added answer to prompt: cq_1 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.0, repetition: 1
# Added answer to prompt: cq_2 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.0, repetition: 1
# Added answer to prompt: cq_2 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.0, repetition: 1
# Added answer to prompt: cq_3 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.0, repetition: 1
# Added answer to prompt: cq_3 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.0, repetition: 1
# Added answer to prompt: cq_4 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.0, repetition: 1
# Added answer to prompt: cq_4 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.0, repetition: 1
# Added answer to prompt: cq_5 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.0, repetition: 1
# Added answer to prompt: cq_5 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.0, repetition: 1
# Added answer to prompt: cq_6 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.0, repetition: 1
# Added answer to prompt: cq_6 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.0, repetition: 1
# Added answer to prompt: cq_7 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.0, repetition: 1
# Added answer to prompt: cq_7 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.0, repetition: 1
# Added answer to prompt: cq_8 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.0, repetition: 1
# Added answer to prompt: cq_8 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.0, repetition: 1
# Added answer to prompt: cq_9 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.0, repetition: 1
# Added answer to prompt: cq_9 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.0, repetition: 1
# Added answer to prompt: 435 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.0, repetition: 1
# Added answer to prompt: 436 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.0, repetition: 1
# Added answer to prompt: 437 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.0, repetition: 1
# Added answer to prompt: 438 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.0, repetition: 1
# Added answer to prompt: 439 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.0, repetition: 1
# Added answer to prompt: 440 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.0, repetition: 1
# Added answer to prompt: 441 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.0, repetition: 1
# Added answer to prompt: 442 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.0, repetition: 1
# Added answer to prompt: cq_1 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.3, repetition: 1
# Added answer to prompt: cq_1 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.3, repetition: 1
# Added answer to prompt: cq_2 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.3, repetition: 1
# Added answer to prompt: cq_2 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.3, repetition: 1
# Added answer to prompt: cq_3 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.3, repetition: 1
# Added answer to prompt: cq_3 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.3, repetition: 1
# Added answer to prompt: cq_4 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.3, repetition: 1
# Added answer to prompt: cq_4 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.3, repetition: 1
# Added answer to prompt: cq_5 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.3, repetition: 1
# Added answer to prompt: cq_5 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.3, repetition: 1
# Added answer to prompt: cq_6 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.3, repetition: 1
# Added answer to prompt: cq_6 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.3, repetition: 1
# Added answer to prompt: cq_7 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.3, repetition: 1
# Added answer to prompt: cq_7 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.3, repetition: 1
# Added answer to prompt: cq_8 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.3, repetition: 1
# Added answer to prompt: cq_8 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.3, repetition: 1
# Added answer to prompt: cq_9 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.3, repetition: 1
# Added answer to prompt: cq_9 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.3, repetition: 1
# Added answer to prompt: 461 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.3, repetition: 1
# Added answer to prompt: 462 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.3, repetition: 1
# Added answer to prompt: 463 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.3, repetition: 1
# Added answer to prompt: 464 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.3, repetition: 1
# Added answer to prompt: 465 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.3, repetition: 1
# Added answer to prompt: 466 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.3, repetition: 1
# Added answer to prompt: 467 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.3, repetition: 1
# Added answer to prompt: 468 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.3, repetition: 1
# Added answer to prompt: cq_1 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.7, repetition: 1
# Added answer to prompt: cq_1 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.7, repetition: 1
# Added answer to prompt: cq_2 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.7, repetition: 1
# Added answer to prompt: cq_2 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.7, repetition: 1
# Added answer to prompt: cq_3 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.7, repetition: 1
# Added answer to prompt: cq_3 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.7, repetition: 1
# Added answer to prompt: cq_4 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.7, repetition: 1
# Added answer to prompt: cq_4 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.7, repetition: 1
# Added answer to prompt: cq_5 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.7, repetition: 1
# Added answer to prompt: cq_5 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.7, repetition: 1
# Added answer to prompt: cq_6 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.7, repetition: 1
# Added answer to prompt: cq_6 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.7, repetition: 1
# Added answer to prompt: cq_7 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.7, repetition: 1
# Added answer to prompt: cq_7 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.7, repetition: 1
# Added answer to prompt: cq_8 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.7, repetition: 1
# Added answer to prompt: cq_8 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.7, repetition: 1
# Added answer to prompt: cq_9 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.7, repetition: 1
# Added answer to prompt: cq_9 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.7, repetition: 1
# Added answer to prompt: 487 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.7, repetition: 1
# Added answer to prompt: 488 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.7, repetition: 1
# Added answer to prompt: 489 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.7, repetition: 1
# Added answer to prompt: 490 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.7, repetition: 1
# Added answer to prompt: 491 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.7, repetition: 1
# Added answer to prompt: 492 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.7, repetition: 1
# Added answer to prompt: 493 for model: ChatGPT-4o-latest (2025-01-29), temperature: 0.7, repetition: 1
# ...
# Added answer to prompt: 877 for model: Meta-Llama-3.1-405B-Instruct-bf16, temperature: 0.3, repetition: 1
# Added answer to prompt: 878 for model: Meta-Llama-3.1-405B-Instruct-bf16, temperature: 0.3, repetition: 1
# Added answer to prompt: 879 for model: Meta-Llama-3.1-405B-Instruct-bf16, temperature: 0.3, repetition: 1
# Added answer to prompt: 880 for model: Meta-Llama-3.1-405B-Instruct-bf16, temperature: 0.3, repetition: 1
# Added answer to prompt: 881 for model: Meta-Llama-3.1-405B-Instruct-bf16, temperature: 0.3, repetition: 1
# Added answer to prompt: 882 for model: Meta-Llama-3.1-405B-Instruct-bf16, temperature: 0.3, repetition: 1
# Added answer to prompt: 883 for model: Meta-Llama-3.1-405B-Instruct-bf16, temperature: 0.3, repetition: 1
# Added answer to prompt: 884 for model: Meta-Llama-3.1-405B-Instruct-bf16, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_1 for model: Meta-Llama-3.1-405B-Instruct-bf16, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_1 for model: Meta-Llama-3.1-405B-Instruct-bf16, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_2 for model: Meta-Llama-3.1-405B-Instruct-bf16, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_2 for model: Meta-Llama-3.1-405B-Instruct-bf16, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_3 for model: Meta-Llama-3.1-405B-Instruct-bf16, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_3 for model: Meta-Llama-3.1-405B-Instruct-bf16, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_4 for model: Meta-Llama-3.1-405B-Instruct-bf16, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_4 for model: Meta-Llama-3.1-405B-Instruct-bf16, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_5 for model: Meta-Llama-3.1-405B-Instruct-bf16, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_5 for model: Meta-Llama-3.1-405B-Instruct-bf16, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_6 for model: Meta-Llama-3.1-405B-Instruct-bf16, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_6 for model: Meta-Llama-3.1-405B-Instruct-bf16, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_7 for model: Meta-Llama-3.1-405B-Instruct-bf16, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_7 for model: Meta-Llama-3.1-405B-Instruct-bf16, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_8 for model: Meta-Llama-3.1-405B-Instruct-bf16, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_8 for model: Meta-Llama-3.1-405B-Instruct-bf16, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_9 for model: Meta-Llama-3.1-405B-Instruct-bf16, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_9 for model: Meta-Llama-3.1-405B-Instruct-bf16, temperature: 0.7, repetition: 1
# Added answer to prompt: 903 for model: Meta-Llama-3.1-405B-Instruct-bf16, temperature: 0.7, repetition: 1
# Added answer to prompt: 904 for model: Meta-Llama-3.1-405B-Instruct-bf16, temperature: 0.7, repetition: 1
# Added answer to prompt: 905 for model: Meta-Llama-3.1-405B-Instruct-bf16, temperature: 0.7, repetition: 1
# Added answer to prompt: 906 for model: Meta-Llama-3.1-405B-Instruct-bf16, temperature: 0.7, repetition: 1
# Added answer to prompt: 907 for model: Meta-Llama-3.1-405B-Instruct-bf16, temperature: 0.7, repetition: 1
# Added answer to prompt: 908 for model: Meta-Llama-3.1-405B-Instruct-bf16, temperature: 0.7, repetition: 1
# Added answer to prompt: 909 for model: Meta-Llama-3.1-405B-Instruct-bf16, temperature: 0.7, repetition: 1
# Added answer to prompt: 910 for model: Meta-Llama-3.1-405B-Instruct-bf16, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_1 for model: Meta-Llama-3.1-405B-Instruct-bf16, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_1 for model: Meta-Llama-3.1-405B-Instruct-bf16, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_2 for model: Meta-Llama-3.1-405B-Instruct-bf16, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_2 for model: Meta-Llama-3.1-405B-Instruct-bf16, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_3 for model: Meta-Llama-3.1-405B-Instruct-bf16, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_3 for model: Meta-Llama-3.1-405B-Instruct-bf16, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_4 for model: Meta-Llama-3.1-405B-Instruct-bf16, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_4 for model: Meta-Llama-3.1-405B-Instruct-bf16, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_5 for model: Meta-Llama-3.1-405B-Instruct-bf16, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_5 for model: Meta-Llama-3.1-405B-Instruct-bf16, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_6 for model: Meta-Llama-3.1-405B-Instruct-bf16, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_6 for model: Meta-Llama-3.1-405B-Instruct-bf16, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_7 for model: Meta-Llama-3.1-405B-Instruct-bf16, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_7 for model: Meta-Llama-3.1-405B-Instruct-bf16, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_8 for model: Meta-Llama-3.1-405B-Instruct-bf16, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_8 for model: Meta-Llama-3.1-405B-Instruct-bf16, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_9 for model: Meta-Llama-3.1-405B-Instruct-bf16, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_9 for model: Meta-Llama-3.1-405B-Instruct-bf16, temperature: 1.0, repetition: 1
# Added answer to prompt: 929 for model: Meta-Llama-3.1-405B-Instruct-bf16, temperature: 1.0, repetition: 1
# Added answer to prompt: 930 for model: Meta-Llama-3.1-405B-Instruct-bf16, temperature: 1.0, repetition: 1
# Added answer to prompt: 931 for model: Meta-Llama-3.1-405B-Instruct-bf16, temperature: 1.0, repetition: 1
# Added answer to prompt: 932 for model: Meta-Llama-3.1-405B-Instruct-bf16, temperature: 1.0, repetition: 1
# Added answer to prompt: 933 for model: Meta-Llama-3.1-405B-Instruct-bf16, temperature: 1.0, repetition: 1
# Added answer to prompt: 934 for model: Meta-Llama-3.1-405B-Instruct-bf16, temperature: 1.0, repetition: 1
# Added answer to prompt: 935 for model: Meta-Llama-3.1-405B-Instruct-bf16, temperature: 1.0, repetition: 1
# Added answer to prompt: 936 for model: Meta-Llama-3.1-405B-Instruct-bf16, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_1 for model: Mistral-Large-2407, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_1 for model: Mistral-Large-2407, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_2 for model: Mistral-Large-2407, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_2 for model: Mistral-Large-2407, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_3 for model: Mistral-Large-2407, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_3 for model: Mistral-Large-2407, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_4 for model: Mistral-Large-2407, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_4 for model: Mistral-Large-2407, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_5 for model: Mistral-Large-2407, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_5 for model: Mistral-Large-2407, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_6 for model: Mistral-Large-2407, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_6 for model: Mistral-Large-2407, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_7 for model: Mistral-Large-2407, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_7 for model: Mistral-Large-2407, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_8 for model: Mistral-Large-2407, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_8 for model: Mistral-Large-2407, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_9 for model: Mistral-Large-2407, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_9 for model: Mistral-Large-2407, temperature: 0.0, repetition: 1
# Added answer to prompt: 955 for model: Mistral-Large-2407, temperature: 0.0, repetition: 1
# Added answer to prompt: 956 for model: Mistral-Large-2407, temperature: 0.0, repetition: 1
# Added answer to prompt: 957 for model: Mistral-Large-2407, temperature: 0.0, repetition: 1
# Added answer to prompt: 958 for model: Mistral-Large-2407, temperature: 0.0, repetition: 1
# Added answer to prompt: 959 for model: Mistral-Large-2407, temperature: 0.0, repetition: 1
# Added answer to prompt: 960 for model: Mistral-Large-2407, temperature: 0.0, repetition: 1
# Added answer to prompt: 961 for model: Mistral-Large-2407, temperature: 0.0, repetition: 1
# Added answer to prompt: 962 for model: Mistral-Large-2407, temperature: 0.0, repetition: 1
# Added answer to prompt: cq_1 for model: Mistral-Large-2407, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_1 for model: Mistral-Large-2407, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_2 for model: Mistral-Large-2407, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_2 for model: Mistral-Large-2407, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_3 for model: Mistral-Large-2407, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_3 for model: Mistral-Large-2407, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_4 for model: Mistral-Large-2407, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_4 for model: Mistral-Large-2407, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_5 for model: Mistral-Large-2407, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_5 for model: Mistral-Large-2407, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_6 for model: Mistral-Large-2407, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_6 for model: Mistral-Large-2407, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_7 for model: Mistral-Large-2407, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_7 for model: Mistral-Large-2407, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_8 for model: Mistral-Large-2407, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_8 for model: Mistral-Large-2407, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_9 for model: Mistral-Large-2407, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_9 for model: Mistral-Large-2407, temperature: 0.3, repetition: 1
# Added answer to prompt: 981 for model: Mistral-Large-2407, temperature: 0.3, repetition: 1
# Added answer to prompt: 982 for model: Mistral-Large-2407, temperature: 0.3, repetition: 1
# Added answer to prompt: 983 for model: Mistral-Large-2407, temperature: 0.3, repetition: 1
# Added answer to prompt: 984 for model: Mistral-Large-2407, temperature: 0.3, repetition: 1
# Added answer to prompt: 985 for model: Mistral-Large-2407, temperature: 0.3, repetition: 1
# Added answer to prompt: 986 for model: Mistral-Large-2407, temperature: 0.3, repetition: 1
# Added answer to prompt: 987 for model: Mistral-Large-2407, temperature: 0.3, repetition: 1
# Added answer to prompt: 988 for model: Mistral-Large-2407, temperature: 0.3, repetition: 1
# Added answer to prompt: cq_1 for model: Mistral-Large-2407, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_1 for model: Mistral-Large-2407, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_2 for model: Mistral-Large-2407, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_2 for model: Mistral-Large-2407, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_3 for model: Mistral-Large-2407, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_3 for model: Mistral-Large-2407, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_4 for model: Mistral-Large-2407, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_4 for model: Mistral-Large-2407, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_5 for model: Mistral-Large-2407, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_5 for model: Mistral-Large-2407, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_6 for model: Mistral-Large-2407, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_6 for model: Mistral-Large-2407, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_7 for model: Mistral-Large-2407, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_7 for model: Mistral-Large-2407, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_8 for model: Mistral-Large-2407, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_8 for model: Mistral-Large-2407, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_9 for model: Mistral-Large-2407, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_9 for model: Mistral-Large-2407, temperature: 0.7, repetition: 1
# Added answer to prompt: 1007 for model: Mistral-Large-2407, temperature: 0.7, repetition: 1
# Added answer to prompt: 1008 for model: Mistral-Large-2407, temperature: 0.7, repetition: 1
# Added answer to prompt: 1009 for model: Mistral-Large-2407, temperature: 0.7, repetition: 1
# Added answer to prompt: 1010 for model: Mistral-Large-2407, temperature: 0.7, repetition: 1
# Added answer to prompt: 1011 for model: Mistral-Large-2407, temperature: 0.7, repetition: 1
# Added answer to prompt: 1012 for model: Mistral-Large-2407, temperature: 0.7, repetition: 1
# Added answer to prompt: 1013 for model: Mistral-Large-2407, temperature: 0.7, repetition: 1
# Added answer to prompt: 1014 for model: Mistral-Large-2407, temperature: 0.7, repetition: 1
# Added answer to prompt: cq_1 for model: Mistral-Large-2407, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_1 for model: Mistral-Large-2407, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_2 for model: Mistral-Large-2407, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_2 for model: Mistral-Large-2407, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_3 for model: Mistral-Large-2407, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_3 for model: Mistral-Large-2407, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_4 for model: Mistral-Large-2407, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_4 for model: Mistral-Large-2407, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_5 for model: Mistral-Large-2407, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_5 for model: Mistral-Large-2407, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_6 for model: Mistral-Large-2407, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_6 for model: Mistral-Large-2407, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_7 for model: Mistral-Large-2407, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_7 for model: Mistral-Large-2407, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_8 for model: Mistral-Large-2407, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_8 for model: Mistral-Large-2407, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_9 for model: Mistral-Large-2407, temperature: 1.0, repetition: 1
# Added answer to prompt: cq_9 for model: Mistral-Large-2407, temperature: 1.0, repetition: 1
# Added answer to prompt: 1033 for model: Mistral-Large-2407, temperature: 1.0, repetition: 1
# Added answer to prompt: 1034 for model: Mistral-Large-2407, temperature: 1.0, repetition: 1
# Added answer to prompt: 1035 for model: Mistral-Large-2407, temperature: 1.0, repetition: 1
# Added answer to prompt: 1036 for model: Mistral-Large-2407, temperature: 1.0, repetition: 1
# Added answer to prompt: 1037 for model: Mistral-Large-2407, temperature: 1.0, repetition: 1
# Added answer to prompt: 1038 for model: Mistral-Large-2407, temperature: 1.0, repetition: 1
# Added answer to prompt: 1039 for model: Mistral-Large-2407, temperature: 1.0, repetition: 1
# Added answer to prompt: 1040 for model: Mistral-Large-2407, temperature: 1.0, repetition: 1
# Merged data saved to prompts_plan_merged.json
